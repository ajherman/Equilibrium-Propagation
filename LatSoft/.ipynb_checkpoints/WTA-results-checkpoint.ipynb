# %%
# %matplotlib inline
import os
import glob
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import re

import torch

from IPython.display import display, Image

import pandas as pd

# %%
import sys
sys.path.append('../')
from output_utils import *

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
runs = getruns()

# %%
runsdf = pd.DataFrame(runs)
runsdf.sort_values('test')
# Out:
#     train  test  epochs   task       model lateral    softmax    thirdphase  \
# 2   93.44 85.19       4  MNIST         CNN                     --thirdphase
# 6   94.80 86.08       5  MNIST         CNN                     --thirdphase
# 4   94.84 90.01       5  MNIST         CNN                     --thirdphase
# 1   90.59 91.69       5  MNIST  LatSoftCNN                     --thirdphase
# 0   91.42 92.74       5  MNIST  LatSoftCNN                     --thirdphase
# 7   92.05 92.99       5  MNIST  LatSoftCNN                     --thirdphase
# 5   92.40 93.24       5  MNIST         CNN          --softmax  --thirdphase
# 8   92.94 93.83       5  MNIST         CNN          --softmax  --thirdphase
# 3   94.50 95.14       5  MNIST         CNN          --softmax  --thirdphase
# 10  94.83 95.82       5  MNIST  LatSoftCNN                     --thirdphase
# 9   95.42 95.89       5  MNIST         CNN                     --thirdphase
# 11  95.21 95.93       5  MNIST         CNN          --softmax  --thirdphase
#
#    randomsign loss activation beta1 beta2 lat-init load  \
# 2              cel      mysig   0.0  0.01
# 6              cel      mysig   0.0  0.01
# 4              cel      mysig   0.0  0.01
# 1              cel      mysig   0.0  0.01
# 0              cel      mysig   0.0  0.01
# 7              cel      mysig   0.0  0.01
# 5              cel      mysig   0.0  0.01
# 8              cel      mysig   0.0  0.01
# 3              cel      mysig   0.0  0.01
# 10             mse      mysig   0.0  0.01
# 9              mse      mysig   0.0  0.01
# 11             mse      mysig   0.0  0.01
#
#                                          dir  \
# 2   results/EP/cel/2023-07-18/11-45-01_gpu1/
# 6   results/EP/cel/2023-07-18/10-34-55_gpu1/
# 4   results/EP/cel/2023-07-18/11-09-23_gpu0/
# 1   results/EP/cel/2023-07-18/11-54-18_gpu0/
# 0   results/EP/cel/2023-07-18/11-09-45_gpu1/
# 7   results/EP/cel/2023-07-18/10-31-15_gpu0/
# 5   results/EP/cel/2023-07-18/11-45-18_gpu1/
# 8   results/EP/cel/2023-07-18/10-22-12_gpu0/
# 3   results/EP/cel/2023-07-18/11-09-06_gpu0/
# 10  results/EP/mse/2023-07-18/13-44-20_gpu0/
# 9   results/EP/mse/2023-07-18/13-44-49_gpu1/
# 11  results/EP/mse/2023-07-18/13-44-34_gpu1/
#
#                                              callline
# 2   ../main.py --task MNIST --model CNN --channels...
# 6   ../main.py --task MNIST --model CNN --channels...
# 4   ../main.py --task MNIST --model CNN --channels...
# 1   ../main.py --task MNIST --model LatSoftCNN --c...
# 0   ../main.py --task MNIST --model LatSoftCNN --c...
# 7   ../main.py --task MNIST --model LatSoftCNN --c...
# 5   ../main.py --task MNIST --model CNN --channels...
# 8   ../main.py --task MNIST --model CNN --channels...
# 3   ../main.py --task MNIST --model CNN --channels...
# 10  ../main.py --task MNIST --model LatSoftCNN --c...
# 9   ../main.py --task MNIST --model CNN --channels...
# 11  ../main.py --task MNIST --model CNN --channels...

# %%
avgdf = runsdf.groupby(['model', 'softmax', 'loss'], as_index=False).mean()
avgdf['model'] = avgdf['model'] + avgdf['softmax'] + ' (' + avgdf['loss'] + ')'
avgdf
# Out:
#                 model    softmax loss  train  test  epochs
# 0           CNN (cel)             cel  94.36 87.09    4.67
# 1           CNN (mse)             mse  95.42 95.89    5.00
# 2  CNN--softmax (cel)  --softmax  cel  93.28 94.07    5.00
# 3  CNN--softmax (mse)  --softmax  mse  95.21 95.93    5.00
# 4    LatSoftCNN (cel)             cel  91.35 92.47    5.00
# 5    LatSoftCNN (mse)             mse  94.83 95.82    5.00

# %%
avgdf[avgdf['loss'] == 'cel'].plot.bar('model', ['test', 'train'], figsize = (9,9))
plt.gca().set_title('Lateral Competition vs. External Softmax Layer')
plt.ylim(85, 95)
plt.savefig('LatSoft_CNN_CNN--softmax_test_and_train_cel.png')

# %%
avgdf[avgdf['loss'] == 'mse'].plot.bar('model', ['test', 'train'], figsize = (9,9))
plt.gca().set_title('Lateral Competition vs. External Softmax Layer')
plt.ylim(90, 100)
plt.savefig('LatSoft_CNN_CNN--softmax_test_and_train_mse.png')
