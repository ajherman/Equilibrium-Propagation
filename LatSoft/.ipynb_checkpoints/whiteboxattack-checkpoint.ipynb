# %%
# %matplotlib inline
import os
import glob
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import re

import torch

from IPython.display import display, Image

import pandas as pd

import numpy as np

# %%
import sys
sys.path.append('../')
from output_utils import *

# %%
runs = getruns()

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
runsdf = pd.DataFrame(runs)
runsdf.sort_values('test', ascending=False)[['task', 'model', 'test', 'train', 'softmax', 'loss', 'load_path', 'load_path_convert', 'competitiontype', 'inhibitstrength', 'pools', 'lat_constraints', 'dir']]
# Out:
#      task       model  test  train  softmax loss load_path load_path_convert  \
# 24  MNIST  LatSoftCNN 96.29  95.87    False  mse
# 19  MNIST  LatSoftCNN 96.24  95.42    False  mse
# 23  MNIST         CNN 96.16  95.45    False  mse
# 22  MNIST         CNN 95.93  95.21     True  mse
# 17  MNIST         CNN 95.89  95.42    False  mse
# 20  MNIST         CNN 95.88  95.06     True  mse
# 18  MNIST  LatSoftCNN 95.82  94.83    False  mse
# 16  MNIST         CNN 95.71  94.77     True  mse
# 21  MNIST         CNN 95.71  95.07    False  mse
# 5   MNIST         CNN 95.14  94.50     True  cel
# 11  MNIST         CNN 93.83  92.94     True  cel
# 7   MNIST         CNN 93.24  92.40     True  cel
# 10  MNIST  LatSoftCNN 92.99  92.05    False  cel
# 2   MNIST  LatSoftCNN 92.74  91.42    False  cel
# 14  MNIST         CNN 92.05  91.29     True  cel
# 3   MNIST  LatSoftCNN 91.69  90.59    False  cel
# 6   MNIST         CNN 90.01  94.84    False  cel
# 13  MNIST  LatSoftCNN 89.97  88.59    False  cel
# 8   MNIST         CNN 86.08  94.80    False  cel
# 9   MNIST  LatSoftCNN 85.76  84.89    False  cel
# 0   MNIST  LatSoftCNN 85.46  84.76    False  cel
# 4   MNIST         CNN 85.19  93.44    False  cel
# 1   MNIST  LatSoftCNN 84.97  84.19    False  cel
# 12  MNIST         CNN 84.57  91.45    False  cel
# 15  MNIST  LatSoftCNN 67.15  51.96    False  cel
#
#            competitiontype  inhibitstrength pools     lat_constraints  \
# 24  feature_inner_products             1.00    mm                  []
# 19  feature_inner_products             1.00    mm                  []
# 23                    none             0.00    mm                  []
# 22                    none             0.00    mm                  []
# 17                    none             0.00    mm                  []
# 20                    none             0.00    mm                  []
# 18  feature_inner_products             1.00    mm                  []
# 16                    none             0.00    mm                  []
# 21                    none             0.00    mm                  []
# 5                     none             0.00    mm                  []
# 11                    none             0.00    mm                  []
# 7                     none             0.00    mm                  []
# 10  feature_inner_products             1.00    mm                  []
# 2   feature_inner_products             1.00    mm                  []
# 14                    none             0.00    aa                  []
# 3   feature_inner_products             1.00    mm                  []
# 6                     none             0.00    mm                  []
# 13  feature_inner_products             1.00    aa          [zerodiag]
# 8                     none             0.00    mm                  []
# 9       uniform_inhibition             0.20    mm          [zerodiag]
# 0   feature_inner_products             1.00    mm  [zerodiag+negReLu]
# 4                     none             0.00    mm                  []
# 1       uniform_inhibition             1.00    mm          [zerodiag]
# 12                    none             0.00    aa                  []
# 15  feature_inner_products             1.00    mm          [zerodiag]
#
#                                          dir
# 24  results/EP/mse/2023-07-18/14-53-22_gpu1/
# 19  results/EP/mse/2023-07-18/14-16-39_gpu0/
# 23  results/EP/mse/2023-07-18/14-48-45_gpu0/
# 22  results/EP/mse/2023-07-18/13-44-34_gpu1/
# 17  results/EP/mse/2023-07-18/13-44-49_gpu1/
# 20  results/EP/mse/2023-07-18/14-16-49_gpu0/
# 18  results/EP/mse/2023-07-18/13-44-20_gpu0/
# 16  results/EP/mse/2023-07-18/14-48-28_gpu1/
# 21  results/EP/mse/2023-07-18/14-16-58_gpu1/
# 5   results/EP/cel/2023-07-18/11-09-06_gpu0/
# 11  results/EP/cel/2023-07-18/10-22-12_gpu0/
# 7   results/EP/cel/2023-07-18/11-45-18_gpu1/
# 10  results/EP/cel/2023-07-18/10-31-15_gpu0/
# 2   results/EP/cel/2023-07-18/11-09-45_gpu1/
# 14  results/EP/cel/2023-07-19/13-19-30_gpu1/
# 3   results/EP/cel/2023-07-18/11-54-18_gpu0/
# 6   results/EP/cel/2023-07-18/11-09-23_gpu0/
# 13  results/EP/cel/2023-07-19/12-09-56_gpu1/
# 8   results/EP/cel/2023-07-18/10-34-55_gpu1/
# 9   results/EP/cel/2023-07-18/17-32-15_gpu1/
# 0   results/EP/cel/2023-07-18/17-21-56_gpu0/
# 4   results/EP/cel/2023-07-18/11-45-01_gpu1/
# 1   results/EP/cel/2023-07-18/16-51-18_gpu1/
# 12  results/EP/cel/2023-07-19/13-54-18_gpu0/
# 15  results/EP/cel/2023-07-19/14-59-31_gpu1/

# %%
path = 'results/EP/mse/2023-07-18/14-53-22_gpu1/' #'results/EP/cel/2023-07-18/10-31-15_gpu0/'
lattest = runsdf[runsdf['dir'] == path]
latmodel = torch.load(path + 'model.pt')
lattest
# Out:
#          model   task pools           archi  channels kernels strides  \
# 23  LatSoftCNN  MNIST    mm  [784, 512, 10]  [32, 64]  [3, 3]  [1, 1]
#
#    paddings    fc    act  ... head_lrs lat_wds save_nrn  load_path_convert  \
# 23   [0, 1]  [10]  mysig  ...       []    None    False
#
#    convert_place_layers tensorboard  train  test  \
# 23                   []        True  95.87 96.29
#
#                                          dir  \
# 23  results/EP/mse/2023-07-18/14-53-22_gpu1/
#
#                                                  call
# 23  ../main.py --task MNIST --model LatSoftCNN --c...
#
# [1 rows x 52 columns]

# %%
path = 'results/EP/cel/2023-07-18/11-09-06_gpu0/'
readouttest = runsdf[runsdf['dir'] == path]
readoutmodel = torch.load('results/EP/cel/2023-07-18/11-09-06_gpu0/' + 'model.pt')
readouttest
# Out:
#   model   task pools           archi  channels kernels strides paddings    fc  \
# 5   CNN  MNIST    mm  [784, 512, 10]  [32, 64]  [3, 3]  [1, 1]   [0, 1]  [10]
#
#      act  ... head_lrs lat_wds save_nrn  load_path_convert  \
# 5  mysig  ...       []    None    False
#
#   convert_place_layers tensorboard  train  test  \
# 5                   []        True  94.50 95.14
#
#                                         dir  \
# 5  results/EP/cel/2023-07-18/11-09-06_gpu0/
#
#                                                 call
# 5  ../main.py --task MNIST --model CNN --channels...
#
# [1 rows x 52 columns]

# %%
import torchvision
import torch.nn.functional as F

# %%
mbs = lattest.mbs.item()
T1 = lattest.T1.item()
device = torch.device(lattest.device.item())

# %%
transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor(),
                                                torchvision.transforms.Normalize(mean=(0.0,), std=(1.0,))])

mnist_dset_train = torchvision.datasets.MNIST('./mnist_pytorch', train=True, transform=transform, target_transform=None, download=True)
train_loader = torch.utils.data.DataLoader(mnist_dset_train, batch_size=mbs, shuffle=True, num_workers=0)

mnist_dset_test = torchvision.datasets.MNIST('./mnist_pytorch', train=False, transform=transform, target_transform=None, download=True)
test_loader = torch.utils.data.DataLoader(mnist_dset_test, batch_size=200, shuffle=False, num_workers=0)

# %%
def evaluate(model, loader, T, device):
    # Evaluate the model on a dataloader with T steps for the dynamics
    model.eval()
    correct=0
    phase = 'Train' if loader.dataset.train else 'Test'

    for x, y in loader:
        x, y = x.to(device), y.to(device)
        neurons = model.init_neurons(x.size(0), device)
        neurons = model(x, y, neurons, T) # dynamics for T time steps

        if not model.softmax:
            pred = torch.argmax(neurons[-1], dim=1).squeeze()  # in this cas prediction is done directly on the last (output) layer of neurons
        else: # prediction is done as a readout of the penultimate layer (output is not part of the system)
            pred = torch.argmax(F.softmax(model.synapses[-1](neurons[-1].view(x.size(0),-1)), dim = 1), dim = 1).squeeze()

        correct += (y == pred).sum().item()


    acc = correct/len(loader.dataset)
    print(phase+' accuracy :\t', acc)
    return correct

# %%
device = torch.device(1)
latmodel = latmodel.to(device)
readoutmodel = readoutmodel.to(device)

# %%
# FGSM attack code
def fgsm_attack(image, epsilon, data_grad):
    # Collect the element-wise sign of the data gradient
    sign_data_grad = data_grad.sign()
    # Create the perturbed image by adjusting each pixel of the input image
    perturbed_image = image + epsilon*sign_data_grad
    # Adding clipping to maintain [0,1] range
    perturbed_image = torch.clamp(perturbed_image, 0, 1)
    # Return the perturbed image
    return perturbed_image

# %%
def attack(model, args, epsilon=0.01, attacks=10):
    mbs = args.mbs.item()
    beta = 0.0
    model = model.to(device)
    
    if args.loss.item()=='mse':
        criterion = torch.nn.MSELoss(reduction='none').to(device)
    elif args.loss.item()=='cel':
        criterion = torch.nn.CrossEntropyLoss(reduction='none').to(device)
    
    T = 10
    
    attackxs = []
    origxs = []
    origpreds = []
    attackedpreds = []
    truthlabels = []
    for s in range(attacks):
        x, y = next(iter(train_loader))
        x = x.to(device)
        x = x.requires_grad_()

        y = y.to(device)
    
    
        neurons = model.init_neurons(mbs, device)
        neurons = model(x, y, neurons, T, beta, criterion, check_thm=True) # check_thm True so grads are retaiend
        
        if args.softmax.item():
            # the prediction is made with softmax[last weights[penultimate layer]]
            pred = model.synapses[-1](neurons[-1].view(mbs,-1))
        else:
            pred = neurons[-1]
        
        origcorrect = torch.eq(pred.max(1).indices, y)
        print('original acc : ', torch.sum(origcorrect)/mbs)

        
        if criterion.__class__.__name__.find('MSE')!=-1:
            L = 0.5*criterion(pred.float(), F.one_hot(y, num_classes=model.nc).float()).sum(dim=1).squeeze()
        else:
            L = criterion(pred.float(), y).squeeze()
        
        model.zero_grad()
        L.sum().backward()
        attackx = fgsm_attack(x, epsilon, x.grad)
        
        
        neurons = model.init_neurons(mbs, device)
        neurons = model(attackx, y, neurons, T, beta, criterion, check_thm=True) # check_thm True so grads are retaiend
        
        if args.softmax.item():
            # the prediction is made with softmax[last weights[penultimate layer]]
            attackpred = model.synapses[-1](neurons[-1].view(mbs,-1))
        else:
            attackpred = neurons[-1]
        
        attackedcorrect = torch.eq(attackpred.max(1).indices, y)
        print('attacked acc : ', torch.sum(attackedcorrect)/mbs)
        
        attacksuccess = torch.logical_and(False == attackedcorrect, True == origcorrect)
        attackxs.append(attackx[attacksuccess].data)
        origxs.append(x[attacksuccess].data)
        origpreds.append(pred[attacksuccess].data)
        attackedpreds.append(attackpred[attacksuccess].data)
        truthlabels.append(y[attacksuccess].data)
            
    return attackxs, origxs, attackedpreds, origpreds, truthlabels

# %%
evaluate(latmodel, test_loader, T1, device)
# Out:
# Test accuracy :	 0.9629
# 9629

# %%
attackx, x, attackpreds, origpreds, truthlabels = attack(latmodel, lattest, epsilon=0.1, attacks=10)
# Out:
# original acc :  tensor(0.9400, device='cuda:1')
# attacked acc :  tensor(0.8000, device='cuda:1')
# original acc :  tensor(0.9900, device='cuda:1')
# attacked acc :  tensor(0.7600, device='cuda:1')
# original acc :  tensor(0.9500, device='cuda:1')
# attacked acc :  tensor(0.8500, device='cuda:1')
# original acc :  tensor(0.9600, device='cuda:1')
# attacked acc :  tensor(0.8400, device='cuda:1')
# original acc :  tensor(0.9500, device='cuda:1')
# attacked acc :  tensor(0.8900, device='cuda:1')
# original acc :  tensor(0.9300, device='cuda:1')
# attacked acc :  tensor(0.7400, device='cuda:1')
# original acc :  tensor(0.9700, device='cuda:1')
# attacked acc :  tensor(0.8500, device='cuda:1')
# original acc :  tensor(0.9500, device='cuda:1')
# attacked acc :  tensor(0.7600, device='cuda:1')
# original acc :  tensor(0.9700, device='cuda:1')
# attacked acc :  tensor(0.8200, device='cuda:1')
# original acc :  tensor(0.9700, device='cuda:1')
# attacked acc :  tensor(0.7400, device='cuda:1')

# %%
np.sum([ax.size(0) for ax in attackx])
# Out:
# 153

# %%
showattacks(attackx, x, attackpreds, origpreds)

# %%
evaluate(readoutmodel, test_loader, T1, device)
# Out:
# Test accuracy :	 0.9514
# 9514

# %%
attackx, x, attackpreds, origpreds, truthlabels = attack(readoutmodel, readouttest, epsilon=0.1, attacks=10)
# Out:
# original acc :  tensor(0.9200, device='cuda:1')
# attacked acc :  tensor(0.7300, device='cuda:1')
# original acc :  tensor(0.9400, device='cuda:1')
# attacked acc :  tensor(0.7500, device='cuda:1')
# original acc :  tensor(0.9100, device='cuda:1')
# attacked acc :  tensor(0.6800, device='cuda:1')
# original acc :  tensor(0.9600, device='cuda:1')
# attacked acc :  tensor(0.7600, device='cuda:1')
# original acc :  tensor(0.8500, device='cuda:1')
# attacked acc :  tensor(0.6500, device='cuda:1')
# original acc :  tensor(0.9700, device='cuda:1')
# attacked acc :  tensor(0.8900, device='cuda:1')
# original acc :  tensor(0.9200, device='cuda:1')
# attacked acc :  tensor(0.7700, device='cuda:1')
# original acc :  tensor(0.9100, device='cuda:1')
# attacked acc :  tensor(0.6800, device='cuda:1')
# original acc :  tensor(0.9300, device='cuda:1')
# attacked acc :  tensor(0.7300, device='cuda:1')
# original acc :  tensor(0.9400, device='cuda:1')
# attacked acc :  tensor(0.7200, device='cuda:1')

# %%
np.sum([ax.size(0) for ax in attackx])
# Out:
# 183

# %%
showattacks(attackx, x, attackpreds, origpreds)

# %%
def showattacks(attackx, x, attackpreds, origpreds):
    fig, axs = plt.subplots(1, len(attackx), figsize=(10,1))
    fig.suptitle("original")
    for idx in range(len(attackx)):
        axs[idx].imshow(x[idx][0][0].data.cpu())
        axs[idx].set_title("pred:" + str(origpreds[idx].max(1).indices[0].data.item()))

    fig, axs = plt.subplots(1, len(attackx), figsize=(10,1))
    fig.suptitle("attacked")
    for idx in range(len(attackx)):
        axs[idx].imshow(attackx[idx][0][0].data.cpu())
        axs[idx].set_title("pred:" + str(attackpreds[idx].max(1).indices[0].data.item()))

    fig, axs = plt.subplots(1, len(attackx), figsize=(10,1))
    fig.suptitle("diff")
    for idx in range(len(attackx)):
        axs[idx].imshow(attackx[idx][0][0].data.cpu() - x[idx][0][0].data.cpu())
        axs[idx].set_title("pred:" + str(attackpreds[idx].max(1).indices[0].data.item()))

# %%
import gc
for obj in gc.get_objects():
    try:
        if torch.is_tensor(obj) or (hasattr(obj, 'data') and torch.is_tensor(obj.data)):
#             print(type(obj), obj.size()
              print(sizeof_fmt(obj.nelement() * obj.element_size()), type(obj), obj.size())
    except:
        pass

import sys
def sizeof_fmt(num, suffix='B'):
    ''' by Fred Cirera,  https://stackoverflow.com/a/1094933/1870254, modified'''
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f %s%s" % (num, 'Yi', suffix)

for name, size in sorted(((name, sys.getsizeof(value)) for name, value in list(
                          locals().items())), key= lambda x: -x[1])[:10]:
    print("{:>30}: {:>8}".format(name, sizeof_fmt(size)))

import sys
def sizeof_fmt(num, suffix='B'):
    ''' by Fred Cirera,  https://stackoverflow.com/a/1094933/1870254, modified'''
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f %s%s" % (num, 'Yi', suffix)

for name, size in sorted(((name, sys.getsizeof(value)) for name, value in list(
                          locals().items())), key= lambda x: -x[1])[:10]:
    print("{:>30}: {:>8}".format(name, sizeof_fmt(size)))

for name, size in sorted(((name, sys.getsizeof(eval(name))) for name in list(
                          dir())), key= lambda x: -x[1])[:10]:
    print("{:>30}: {:>8}".format(name, sizeof_fmt(size)))

x.element_size() * x.nelement()

del neurons

torch.cuda.empty_cache()

print(torch.cuda.memory_summary(device))

model.zero_grad()

from torch.profiler import profile, record_function, ProfilerActivity
model = latmodel
beta_1 = 0.0
beta_2 = 0.1
betas = [beta_1, beta_2]
def copy(neurons):
    copy = []
    for n in neurons:
        copy.append(torch.empty_like(n).copy_(n.data).requires_grad_())
    return copy

criterion = torch.nn.CrossEntropyLoss()
with profile(activities=[
        ProfilerActivity.CPU, ProfilerActivity.CUDA], profile_memory=True, with_stack=True, record_shapes=True) as prof:
    with record_function("init_neurons"):
        neurons = model.init_neurons(x.size(0), device)
    with record_function("model_inference"):
        model(x, y, neurons, 10, beta=beta_1, criterion=criterion)
    neurons_1 = copy(neurons)
    model(x, y, neurons, 10, beta=beta_2, criterion=criterion)
    neurons_2 = copy(neurons)
    with record_function("synapse_update"):
        model.compute_syn_grads(x, y, neurons_1, neurons_2, betas, criterion)

print(prof.key_averages(group_by_stack_n=5).table(sort_by="cuda_memory_usage", row_limit=10))
